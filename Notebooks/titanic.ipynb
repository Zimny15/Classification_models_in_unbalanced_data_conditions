# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/titanic_agh.csv")
print(df.shape)
print(df.head())
print(df.info())
# Out:
# (714, 7)
#    ID_pasażera  Przeżył  Klasa    Płeć  Wiek  Cena_biletu Port_zaokrętowania
# 0            1        0      3    male  22.0       7.2500                  S
# 1            2        1      1  female  38.0      71.2833                  C
# 2            3        1      3  female  26.0       7.9250                  S
# 3            4        1      1  female  35.0      53.1000                  S
# 4            5        0      3    male  35.0       8.0500                  S
# <class 'pandas.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID_pasażera         714 non-null    int64
#  1   Przeżył             714 non-null    int64
#  2   Klasa               714 non-null    int64
#  3   Płeć                714 non-null    str
#  4   Wiek                714 non-null    float64
#  5   Cena_biletu         714 non-null    float64
#  6   Port_zaokrętowania  712 non-null    str
# dtypes: float64(2), int64(3), str(2)
# memory usage: 39.2 KB
# None

# %%
df.isnull().sum().sort_values(ascending=False)
#df.nunique().sort_values(ascending=False)
#df["Przeżył"].value_counts()
# Out:
# Płeć                  714
# Port_zaokrętowania      2
# ID_pasażera             0
# Klasa                   0
# Przeżył                 0
# Wiek                    0
# Cena_biletu             0
# dtype: int64

# %%
df.drop(columns=["ID_pasażera"])
df["Płeć"] = df["Płeć"].map({"male": 0, "female": 1})
df["Port_zaokrętowania"] = df["Port_zaokrętowania"].map({"S": 0, "C": 1, "Q": 2})
